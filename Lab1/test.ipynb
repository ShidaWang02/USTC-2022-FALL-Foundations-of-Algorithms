# %%
import time
import pandas as pd
import numpy as np

# data = pd.read_csv(r'data.txt',sep='\s+')
# data = np.loadtxt('data.txt')
file = open('data.txt','r')
fdata = file.readlines()
fdata.remove('100000\n')
data0 = []
for i in fdata:
    tmp = i.split(' ')
    data0.append(tmp)
data1=data0[0]
data1.remove('')
data = [int(i) for i in data1]


data
# Out:
# [42705,
#  54648,
#  73121,
#  30162,
#  20466,
#  91547,
#  78844,
#  74008,
#  50026,
#  87262,
#  72703,
#  57139,
#  76657,
#  72352,
#  61167,
#  82044,
#  18356,
#  51714,
#  29354,
#  11521,
#  18495,
#  18805,
#  890,
#  79644,
#  83685,
#  31873,
#  31683,
#  68823,
#  39999,
#  8333,
#  40500,
#  57431,
#  66096,
#  70956,
#  80504,
#  26315,
#  36146,
#  53314,
#  27314,
#  49134,
#  8669,
#  16731,
#  69025,
#  84706,
#  37683,
#  80134,
#  43490,
#  82108,
#  31264,
#  61278,
#  55763,
#  3092,
#  69511,
#  80715,
#  26126,
#  83430,
#  32770,
#  3868,
#  69681,
#  2166,
#  46891,
#  67014,
#  75584,
#  343,
#  30969,
#  30046,
#  2404,
#  90834,
#  94839,
#  22337,
#  71872,
#  37991,
#  56342,
#  64708,
#  60665,
#  29637,
#  43114,
#  44482,
#  35645,
#  88212,
#  10696,
#  57348,
#  49138,
#  44678,
#  4056,
#  1227,
#  5239,
#  93999,
#  68867,
#  97925,
#  95436,
#  78975,
#  65655,
#  82518,
#  51019,
#  15269,
#  89737,
#  89951,
#  12272,
#  32902,
#  53979,
# ...

# %%
init_time = time.time()
data_sorted = data.sort()
t = time.time()-init_time
print(t)
# Out:
# 0.0413815975189209
